# %% [markdown]
# # Importing Modules, Setting Up Regular Expressions and HTTP Pool

# %%
import re
import urllib3
import certifi
import json
import pymongo
import pandas
import time

# Setting up all relevant regular expressions
# Score_regex source: Stuart Ketcham from DA320
title_regex = re.compile(r"class=\"title\"><h3(.+)</h3>")
date_regex = re.compile(r"class=\"clamp-details\">\s+<span>(.+)</span>")
description_regex = re.compile(r"<div class=\"summary\">\s*([\S\s]+?)\s*<\/div>")
score_regex = re.compile(r">(.*)<\/div>\s+<\/a>\s+<\/div>\s+<s")
image_regex = re.compile(r"<a href=\"/movie/.*\"><img src=\"(.*)\" alt=\"")

# Setting up an HTTP pool for connections
http = urllib3.PoolManager(ca_certs=certifi.where())

# %% [markdown]
# # Connecting to MongoDB

# %%
# Loading the json file that contains my secret MongoDB connection string
with open ('/Users/hong.vince/Desktop/DA320/credentials.json') as u:
    data = json.load(u)

    secret_key = data['my-secret-key']

# Connecting to the database using known good certificates
client = pymongo.MongoClient(secret_key, tlsCAFile=certifi.where())

# Fetching my database titled "DA320"
da320_database = client['DA320']

# Accessing my collections from my "DA320" database
allCollections = da320_database['metacritic']

# %% [markdown]
# # Creating the Web Scraping Function

# %%
def metacritic_scraper(year: int, page: int) -> pandas.DataFrame:

    # Fetching webpage
    url = f"https://www.metacritic.com/browse/movies/score/metascore/year/filtered?year_selected={year}&sort=desc&view=detailed&page={page}"
    response = http.request('GET', url, headers={'User-Agent': 'Mozilla/5.0'})
    datastring = str(response.data, "utf-8")

    #Executing all the regular expressions
    titles = title_regex.findall(datastring)
    dates = date_regex.findall(datastring)
    descriptions = description_regex.findall(datastring)
    scores = score_regex.findall(datastring)
    images = image_regex.findall(datastring)

    # Returning a unified collection
    dataset = {"title": titles, "date": dates, "description": descriptions, "score": scores, "image": images}
    return pandas.DataFrame(dataset)

# %% [markdown]
# # Looping Through Years and Pages

# %%
# Writing a CSV file with the data
for year in range (2000, 2023):
    page = 0 
    print(f"Collecting data for {year} page {page}...")

    # Retry a page multiple times if necessary
    while True:
        data = metacritic_scraper(year, page)

        # Stop when we reach a page with zero rows
        if len(data) == 0:
            break

        # Converting the dataframe into a list of movies to insert into MongoDB
        movies_to_insert =[]
        for row in data.itertuples():
            movie = {
                "title": row.title,
                "release_date": row.date,
                "description": row.description,
                "metascore": row.score,
                "image_url": row.image,
            }
            movies_to_insert.append(movie)

        # Insert records into MongoDB
        print(f"Inserting {len(movies_to_insert)} movies for the year {year} page {page}")
        allCollections.insert_many(movies_to_insert)
        page = page + 1
# Out:
# Collecting data for 2000 page 0...
# Inserting 100 movies for the year 2000 page 0
# Inserting 100 movies for the year 2000 page 1
# Inserting 100 movies for the year 2000 page 2
# Inserting 65 movies for the year 2000 page 3
# Collecting data for 2001 page 0...
# Inserting 100 movies for the year 2001 page 0
# Inserting 100 movies for the year 2001 page 1
# Inserting 100 movies for the year 2001 page 2
# Inserting 85 movies for the year 2001 page 3
# Collecting data for 2002 page 0...
# Inserting 100 movies for the year 2002 page 0
# Inserting 100 movies for the year 2002 page 1
# Inserting 100 movies for the year 2002 page 2
# Inserting 100 movies for the year 2002 page 3
# Inserting 30 movies for the year 2002 page 4
# Collecting data for 2003 page 0...
# Inserting 100 movies for the year 2003 page 0
# Inserting 100 movies for the year 2003 page 1
# Inserting 100 movies for the year 2003 page 2
# Inserting 100 movies for the year 2003 page 3
# Inserting 9 movies for the year 2003 page 4
# Collecting data for 2004 page 0...
# Inserting 100 movies for the year 2004 page 0
# Inserting 100 movies for the year 2004 page 1
# Inserting 100 movies for the year 2004 page 2
# Inserting 100 movies for the year 2004 page 3
# Inserting 76 movies for the year 2004 page 4
# Collecting data for 2005 page 0...
# Inserting 100 movies for the year 2005 page 0
# Inserting 100 movies for the year 2005 page 1
# Inserting 100 movies for the year 2005 page 2
# Inserting 100 movies for the year 2005 page 3
# Inserting 100 movies for the year 2005 page 4
# Inserting 15 movies for the year 2005 page 5
# Collecting data for 2006 page 0...
# Inserting 100 movies for the year 2006 page 0
# Inserting 100 movies for the year 2006 page 1
# Inserting 100 movies for the year 2006 page 2
# Inserting 100 movies for the year 2006 page 3
# Inserting 100 movies for the year 2006 page 4
# Inserting 26 movies for the year 2006 page 5
# Collecting data for 2007 page 0...
# Inserting 100 movies for the year 2007 page 0
# Inserting 100 movies for the year 2007 page 1
# Inserting 100 movies for the year 2007 page 2
# Inserting 100 movies for the year 2007 page 3
# Inserting 67 movies for the year 2007 page 4
# Collecting data for 2008 page 0...
# Inserting 100 movies for the year 2008 page 0
# Inserting 100 movies for the year 2008 page 1
# Inserting 100 movies for the year 2008 page 2
# Inserting 100 movies for the year 2008 page 3
# Inserting 28 movies for the year 2008 page 4
# Collecting data for 2009 page 0...
# Inserting 100 movies for the year 2009 page 0
# Inserting 100 movies for the year 2009 page 1
# Inserting 100 movies for the year 2009 page 2
# Inserting 100 movies for the year 2009 page 3
# Inserting 4 movies for the year 2009 page 4
# Collecting data for 2010 page 0...
# Inserting 100 movies for the year 2010 page 0
# Inserting 100 movies for the year 2010 page 1
# Inserting 100 movies for the year 2010 page 2
# Inserting 100 movies for the year 2010 page 3
# Inserting 37 movies for the year 2010 page 4
# Collecting data for 2011 page 0...
# Inserting 100 movies for the year 2011 page 0
# Inserting 100 movies for the year 2011 page 1
# Inserting 100 movies for the year 2011 page 2
# Inserting 100 movies for the year 2011 page 3
# Inserting 100 movies for the year 2011 page 4
# Inserting 41 movies for the year 2011 page 5
# Collecting data for 2012 page 0...
# Inserting 100 movies for the year 2012 page 0
# Inserting 100 movies for the year 2012 page 1
# Inserting 100 movies for the year 2012 page 2
# Inserting 100 movies for the year 2012 page 3
# Inserting 100 movies for the year 2012 page 4
# Inserting 72 movies for the year 2012 page 5
# Collecting data for 2013 page 0...
# Inserting 100 movies for the year 2013 page 0
# Inserting 100 movies for the year 2013 page 1
# Inserting 100 movies for the year 2013 page 2
# Inserting 100 movies for the year 2013 page 3
# Inserting 100 movies for the year 2013 page 4
# Inserting 100 movies for the year 2013 page 5
# Inserting 25 movies for the year 2013 page 6
# Collecting data for 2014 page 0...
# Inserting 100 movies for the year 2014 page 0
# Inserting 100 movies for the year 2014 page 1
# Inserting 100 movies for the year 2014 page 2
# Inserting 100 movies for the year 2014 page 3
# Inserting 100 movies for the year 2014 page 4
# Inserting 100 movies for the year 2014 page 5
# Inserting 62 movies for the year 2014 page 6
# Collecting data for 2015 page 0...
# Inserting 100 movies for the year 2015 page 0
# Inserting 100 movies for the year 2015 page 1
# Inserting 100 movies for the year 2015 page 2
# Inserting 100 movies for the year 2015 page 3
# Inserting 100 movies for the year 2015 page 4
# Inserting 100 movies for the year 2015 page 5
# Inserting 40 movies for the year 2015 page 6
# Collecting data for 2016 page 0...
# Inserting 100 movies for the year 2016 page 0
# Inserting 100 movies for the year 2016 page 1
# Inserting 100 movies for the year 2016 page 2
# Inserting 100 movies for the year 2016 page 3
# Inserting 100 movies for the year 2016 page 4
# Inserting 100 movies for the year 2016 page 5
# Inserting 13 movies for the year 2016 page 6
# Collecting data for 2017 page 0...
# Inserting 100 movies for the year 2017 page 0
# Inserting 100 movies for the year 2017 page 1
# Inserting 100 movies for the year 2017 page 2
# Inserting 100 movies for the year 2017 page 3
# Inserting 100 movies for the year 2017 page 4
# Inserting 100 movies for the year 2017 page 5
# Inserting 13 movies for the year 2017 page 6
# Collecting data for 2018 page 0...
# Inserting 100 movies for the year 2018 page 0
# Inserting 100 movies for the year 2018 page 1
# Inserting 100 movies for the year 2018 page 2
# Inserting 100 movies for the year 2018 page 3
# Inserting 100 movies for the year 2018 page 4
# Inserting 100 movies for the year 2018 page 5
# Inserting 11 movies for the year 2018 page 6
# Collecting data for 2019 page 0...
# Inserting 100 movies for the year 2019 page 0
# Inserting 100 movies for the year 2019 page 1
# Inserting 100 movies for the year 2019 page 2
# Inserting 100 movies for the year 2019 page 3
# Inserting 100 movies for the year 2019 page 4
# Inserting 69 movies for the year 2019 page 5
# Collecting data for 2020 page 0...
# Inserting 100 movies for the year 2020 page 0
# Inserting 100 movies for the year 2020 page 1
# Inserting 100 movies for the year 2020 page 2
# Inserting 100 movies for the year 2020 page 3
# Inserting 100 movies for the year 2020 page 4
# Inserting 43 movies for the year 2020 page 5
# Collecting data for 2021 page 0...
# Inserting 100 movies for the year 2021 page 0
# Inserting 100 movies for the year 2021 page 1
# Inserting 100 movies for the year 2021 page 2
# Inserting 100 movies for the year 2021 page 3
# Inserting 100 movies for the year 2021 page 4
# Inserting 39 movies for the year 2021 page 5
# Collecting data for 2022 page 0...
# Inserting 100 movies for the year 2022 page 0
# Inserting 100 movies for the year 2022 page 1
# Inserting 100 movies for the year 2022 page 2
# Inserting 100 movies for the year 2022 page 3
# Inserting 75 movies for the year 2022 page 4
